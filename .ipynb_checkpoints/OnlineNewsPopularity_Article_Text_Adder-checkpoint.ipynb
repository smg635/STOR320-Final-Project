# %%
import urllib.request
import re
import html2text as h2t
import pandas as pd

# %%
OnlineNewsPopularityTraining = pd.read_csv("./data/OnlineNewsPopularityTraining.csv")
OnlineNewsPopularityTest = pd.read_csv("./data/OnlineNewsPopularityTest.csv")

# %%
TrainingLinks = OnlineNewsPopularityTraining.url
TestLinks = OnlineNewsPopularityTest.url

TrainingText = [''] * OnlineNewsPopularityTraining.shape[0]
TestText = [''] * OnlineNewsPopularityTest.shape[0]

# %%
for idx, link in enumerate(TrainingLinks):
    if idx%500 == 0:
        print(idx)
    if idx > 50:
        break
        
    fp = urllib.request.urlopen(link)
    mybytes = fp.read()

    mystr = mybytes.decode("utf8")
    fp.close()

    # print(mystr)
    
    try:
        mystr = re.search("(?<=<section class='article-content'>)[\s\S]+(?=<\/section>)", mystr).group()
    except:
        mystr = ""
        
    h = h2t.HTML2Text()

    TrainingText[idx] = (h.handle(mystr))
# Out:
# 0

# %%
for idx, link in enumerate(TestLinks):
    if idx%500 == 0:
        print(idx)
    if idx > 50:
        break
    
    fp = urllib.request.urlopen(link)
    mybytes = fp.read()

    mystr = mybytes.decode("utf8")
    fp.close()

    # print(mystr)
    try:
        mystr = re.search("(?<=<section class='article-content'>)[\s\S]+(?=<\/section>)", mystr).group()
    except:
        mystr = ""
    
    h = h2t.HTML2Text()

    TestText[idx] = (h.handle(mystr))
# Out:
# 0

# %%
len(TrainingText)
# Out:
# 31716

# %%
len(TestText)
# Out:
# 7928

# %%
OnlineNewsPopularityTraining['text'] = TrainingText

# %%
OnlineNewsPopularityTest['text'] = TestText

# %%
OnlineNewsPopularityTraining
# Out:
#                                                      url  timedelta  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...        731
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...        731
# 2      http://mashable.com/2013/01/07/apple-40-billio...        731
# 3      http://mashable.com/2013/01/07/astronaut-notre...        731
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/        731
# ...                                                  ...        ...
# 31711  http://mashable.com/2014/12/27/north-korea-int...          8
# 31712  http://mashable.com/2014/12/27/nypd-rafael-ram...          8
# 31713  http://mashable.com/2014/12/27/seth-rogen-jame...          8
# 31714     http://mashable.com/2014/12/27/ukraine-blasts/          8
# 31715  http://mashable.com/2014/12/27/youtube-channel...          8
#
#        n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0                  12               219         0.663594               1.0
# 1                   9               255         0.604743               1.0
# 2                   9               211         0.575130               1.0
# 3                   9               531         0.503788               1.0
# 4                  13              1072         0.415646               1.0
# ...               ...               ...              ...               ...
# 31711               8              2509         0.348878               1.0
# 31712              13              1629         0.425711               1.0
# 31713              12               328         0.696296               1.0
# 31714               6               682         0.539493               1.0
# 31715              10               157         0.701987               1.0
#
#        n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                      0.815385          4               2         1  ...
# 1                      0.791946          3               1         1  ...
# 2                      0.663866          3               1         1  ...
# 3                      0.665635          9               0         1  ...
# 4                      0.540890         19              19        20  ...
# ...                         ...        ...             ...       ...  ...
# 31711                  0.464923         23               1        10  ...
# 31712                  0.606092         15              12         6  ...
# 31713                  0.885057          9               7         3  ...
# 31714                  0.692661         10               1         1  ...
# 31715                  0.846154          1               1         0  ...
#
#        avg_negative_polarity  min_negative_polarity  max_negative_polarity  \
# 0                  -0.350000                 -0.600              -0.200000
# 1                  -0.118750                 -0.125              -0.100000
# 2                  -0.466667                 -0.800              -0.133333
# 3                  -0.369697                 -0.600              -0.166667
# 4                  -0.220192                 -0.500              -0.050000
# ...                      ...                    ...                    ...
# 31711              -0.231612                 -0.600              -0.050000
# 31712              -0.429534                 -1.000              -0.050000
# 31713              -0.211111                 -0.400              -0.100000
# 31714              -0.205246                 -0.500              -0.012500
# 31715              -0.200000                 -0.200              -0.200000
#
#        title_subjectivity  title_sentiment_polarity  abs_title_subjectivity  \
# 0                0.500000                 -0.187500                0.000000
# 1                0.000000                  0.000000                0.500000
# 2                0.000000                  0.000000                0.500000
# 3                0.000000                  0.000000                0.500000
# 4                0.454545                  0.136364                0.045455
# ...                   ...                       ...                     ...
# 31711            0.000000                  0.000000                0.500000
# 31712            0.783333                 -0.600000                0.283333
# 31713            0.300000                  1.000000                0.200000
# 31714            0.000000                  0.000000                0.500000
# 31715            0.333333                  0.250000                0.166667
#
#        abs_title_sentiment_polarity  shares  popular  \
# 0                          0.187500     593        0
# 1                          0.000000     711        0
# 2                          0.000000    1500        0
# 3                          0.000000    1200        0
# 4                          0.136364     505        0
# ...                             ...     ...      ...
# 31711                      0.000000    1700        0
# 31712                      0.600000    1400        0
# 31713                      1.000000    1900        0
# 31714                      0.000000    1100        0
# 31715                      0.250000    1300        0
#
#                                                     text
# 0      Having trouble finding something to watch on\n...
# 1      The [Associated Press](https://mashable.com/ca...
# 2      It looks like 2012 was a pretty good year for ...
# 3      When it comes to college football, NASA astron...
# 4      LAS VEGAS — Sharing photos and videos on your ...
# ...                                                  ...
# 31711
# 31712
# 31713
# 31714
# 31715
#
# [31716 rows x 63 columns]

# %%
OnlineNewsPopularityTest

# %%
OnlineNewsPopularityTraining.to_csv(OnlineNewsPopularityTrainingWithText, encoding='utf-8', index=False)
OnlineNewsPopularityTest.to_csv(OnlineNewsPopularityTestWithText, encoding='utf-8', index=False)
